# %% [markdown]
# <a href="https://colab.research.google.com/github/rmshruti3082006/24cs403/blob/main/CIE4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf
from tensorflow.keras.datasets import mnist
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Flatten
from tensorflow.keras.callbacks import TensorBoard
(x_train, y_train), (x_test, y_test) = mnist.load_data()
x_train, y_train = x_test / 255.0, y_test / 255.0
model = Sequential([
Flatten(input_shape=(28, 28)),
Dense(128, activation='relu'),
Dense(10, activation='softmax')
])
model.compile(optimizer='adam',
loss='sparse_categorical_crossentropy',
metrics=['accuracy'])
tensorboard_callback = TensorBoard(log_dir='./logs', histogram_freq=1)
model.fit(x_train, y_train, epochs=5, batch_size=32,
validation_data=(x_test, y_test),
callbacks=[tensorboard_callback])
test_loss, test_acc = model.evaluate(x_test, y_test)
print('Test accuracy:', test_acc)
# %tensorboard --logdir=./logs
# Out:
# Epoch 1/5
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/reshaping/flatten.py:37: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.0979 - loss: 0.0975 - val_accuracy: 0.0980 - val_loss: 4343.2139
# Epoch 2/5
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.0922 - loss: 7.1167e-05 - val_accuracy: 0.0980 - val_loss: 5006.6377
# Epoch 3/5
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.0984 - loss: 1.6630e-05 - val_accuracy: 0.0980 - val_loss: 5433.7378
# Epoch 4/5
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.0957 - loss: 8.5078e-06 - val_accuracy: 0.0980 - val_loss: 5739.5078
# Epoch 5/5
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.0999 - loss: 4.9607e-06 - val_accuracy: 0.0980 - val_loss: 5988.2573
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.0924 - loss: 5710.7959
# Test accuracy: 0.09799999743700027
# UsageError: Line magic function `%tensorboard` not found.
